# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import time
import xml.etree.ElementTree as ET

import cv2
import matplotlib.pyplot as plt
import numpy as np
import timm
import torch
import torch.nn as nn
import torchvision
from PIL import Image
from sklearn.model_selection import train_test_split
from torch .nn import functional as F
from torch . utils . data import DataLoader , Dataset
from torchvision import transforms

# %% [markdown]
# # Text Recognition

# %%
import os
import xml.etree.ElementTree as ET

def extract_data_from_xml(root_dir):
    xml_path = os.path.join(root_dir, "words.xml")
    tree = ET.parse(xml_path)
    root = tree.getroot()

    img_paths = []
    img_sizes = []
    img_labels = []
    bboxes = []

    for img in root:
        bbs_of_img = []
        labels_of_img = []

        for bbs in img.findall("taggedRectangles"):
            for bb in bbs:
                # check non-alphabet and non-number
                if not bb[0].text.isalnum():
                    continue

                if "e" in bb[0].text.lower() or "n" in bb[0].text.lower():
                    continue

                bbs_of_img.append([
                    float(bb.attrib["x"]),
                    float(bb.attrib["y"]),
                    float(bb.attrib["width"]),
                    float(bb.attrib["height"]),
                ])
                labels_of_img.append(bb[0].text.lower())

        img_path = os.path.join(root_dir, img[0].text)
        img_paths.append(img_path)
        img_sizes.append((int(img[1].attrib["x"]), int(img[1].attrib["y"])))
        bboxes.append(bbs_of_img)
        img_labels.append(labels_of_img)

    return img_paths, img_sizes, img_labels, bboxes

dataset_dir = "/content/drive/MyDrive/Google Colab/SceneTrialTrain"
img_paths, img_sizes, img_labels, bboxes = extract_data_from_xml(dataset_dir)

# %%
import os
from PIL import Image
import numpy as np

def split_bounding_boxes(img_paths, img_labels, bboxes, save_dir):
    os.makedirs(save_dir, exist_ok=True)

    count = 0
    labels = []  # List to store labels

    for img_path, img_label, bbs in zip(img_paths, img_labels, bboxes):
        img = Image.open(img_path)

        for label, bb in zip(img_label, bbs):
            # Crop image
            cropped_img = img.crop((bb[0], bb[1], bb[0] + bb[2], bb[1] + bb[3]))

            # Filter out if 90% of the cropped image is black or white
            if np.mean(cropped_img) < 35 or np.mean(cropped_img) > 220:
                continue

            if cropped_img.size[0] < 10 or cropped_img.size[1] < 10:
                continue

            # Save image
            filename = f"{count:06d}.jpg"
            cropped_img.save(os.path.join(save_dir, filename))

            new_img_path = os.path.join(save_dir, filename)

            label = new_img_path + "\t" + label

            labels.append(label)  # Append label to the list

            count += 1

    print(f"Created {count} images")

    # Write labels to a text file
    with open(os.path.join(save_dir, "labels.txt"), "w") as f:
        for label in labels:
            print(label)
            f.write(f"{label}\n")

# Example usage
save_dir = "datasets/ocr_dataset"
split_bounding_boxes(img_paths, img_labels, bboxes, save_dir)
# Out:
# Created 392 images
# datasets/ocr_dataset/000000.jpg	36
# datasets/ocr_dataset/000001.jpg	250
# datasets/ocr_dataset/000002.jpg	a
# datasets/ocr_dataset/000003.jpg	roll
# datasets/ocr_dataset/000004.jpg	local
# datasets/ocr_dataset/000005.jpg	toubrs
# datasets/ocr_dataset/000006.jpg	83
# datasets/ocr_dataset/000007.jpg	73
# datasets/ocr_dataset/000008.jpg	of
# datasets/ocr_dataset/000009.jpg	spirits
# datasets/ocr_dataset/000010.jpg	both
# datasets/ocr_dataset/000011.jpg	digital
# datasets/ocr_dataset/000012.jpg	for
# datasets/ocr_dataset/000013.jpg	j
# datasets/ocr_dataset/000014.jpg	dlr
# datasets/ocr_dataset/000015.jpg	3p
# datasets/ocr_dataset/000016.jpg	a4382
# datasets/ocr_dataset/000017.jpg	6210
# datasets/ocr_dataset/000018.jpg	dlr
# datasets/ocr_dataset/000019.jpg	3p
# datasets/ocr_dataset/000020.jpg	data
# datasets/ocr_dataset/000021.jpg	bott
# datasets/ocr_dataset/000022.jpg	jack
# datasets/ocr_dataset/000023.jpg	third
# datasets/ocr_dataset/000024.jpg	fifth
# datasets/ocr_dataset/000025.jpg	id
# datasets/ocr_dataset/000026.jpg	willcocks
# datasets/ocr_dataset/000027.jpg	it
# datasets/ocr_dataset/000028.jpg	s
# datasets/ocr_dataset/000029.jpg	t
# datasets/ocr_dataset/000030.jpg	of
# datasets/ocr_dataset/000031.jpg	with
# datasets/ocr_dataset/000032.jpg	to
# datasets/ocr_dataset/000033.jpg	ltd
# datasets/ocr_dataset/000034.jpg	ta11
# datasets/ocr_dataset/000035.jpg	6tb
# datasets/ocr_dataset/000036.jpg	to
# datasets/ocr_dataset/000037.jpg	sixth
# datasets/ocr_dataset/000038.jpg	stuart
# datasets/ocr_dataset/000039.jpg	rtificial
# datasets/ocr_dataset/000040.jpg	a
# datasets/ocr_dataset/000041.jpg	approach
# datasets/ocr_dataset/000042.jpg	of
# datasets/ocr_dataset/000043.jpg	of
# datasets/ocr_dataset/000044.jpg	artificial
# datasets/ocr_dataset/000045.jpg	for
# datasets/ocr_dataset/000046.jpg	o
# datasets/ocr_dataset/000047.jpg	c
# datasets/ocr_dataset/000048.jpg	i
# datasets/ocr_dataset/000049.jpg	for
# datasets/ocr_dataset/000050.jpg	of
# datasets/ocr_dataset/000051.jpg	v10
# datasets/ocr_dataset/000052.jpg	marco
# datasets/ocr_dataset/000053.jpg	wrox
# datasets/ocr_dataset/000054.jpg	wrox
# datasets/ocr_dataset/000055.jpg	support
# datasets/ocr_dataset/000056.jpg	at
# datasets/ocr_dataset/000057.jpg	support
# datasets/ocr_dataset/000058.jpg	wroxcom
# datasets/ocr_dataset/000059.jpg	at
# datasets/ocr_dataset/000060.jpg	www
# datasets/ocr_dataset/000061.jpg	wroxcom
# datasets/ocr_dataset/000062.jpg	wroxcom
# datasets/ocr_dataset/000063.jpg	at
# datasets/ocr_dataset/000064.jpg	p2p
# datasets/ocr_dataset/000065.jpg	to
# datasets/ocr_dataset/000066.jpg	for
# datasets/ocr_dataset/000067.jpg	lights
# datasets/ocr_dataset/000068.jpg	marlboro
# datasets/ocr_dataset/000069.jpg	2001
# datasets/ocr_dataset/000070.jpg	argos
# datasets/ocr_dataset/000071.jpg	philips
# datasets/ocr_dataset/000072.jpg	fisio
# datasets/ocr_dataset/000073.jpg	most
# datasets/ocr_dataset/000074.jpg	with
# datasets/ocr_dataset/000075.jpg	to
# datasets/ocr_dataset/000076.jpg	your
# datasets/ocr_dataset/000077.jpg	call
# datasets/ocr_dataset/000078.jpg	150
# datasets/ocr_dataset/000079.jpg	2002
# datasets/ocr_dataset/000080.jpg	of
# datasets/ocr_dataset/000081.jpg	music
# datasets/ocr_dataset/000082.jpg	o
# datasets/ocr_dataset/000083.jpg	with
# datasets/ocr_dataset/000084.jpg	java
# datasets/ocr_dataset/000085.jpg	tm
# datasets/ocr_dataset/000086.jpg	of
# datasets/ocr_dataset/000087.jpg	xml
# datasets/ocr_dataset/000088.jpg	soap
# datasets/ocr_dataset/000089.jpg	wsdl
# datasets/ocr_dataset/000090.jpg	uddi
# datasets/ocr_dataset/000091.jpg	aircraft
# datasets/ocr_dataset/000092.jpg	blast
# datasets/ocr_dataset/000093.jpg	low
# datasets/ocr_dataset/000094.jpg	physical
# datasets/ocr_dataset/000095.jpg	alligator
# datasets/ocr_dataset/000096.jpg	115mm
# datasets/ocr_dataset/000097.jpg	with
# datasets/ocr_dataset/000098.jpg	road
# datasets/ocr_dataset/000099.jpg	stop
# datasets/ocr_dataset/000100.jpg	clock
# datasets/ocr_dataset/000101.jpg	by
# datasets/ocr_dataset/000102.jpg	car
# datasets/ocr_dataset/000103.jpg	marks
# datasets/ocr_dataset/000104.jpg	to
# datasets/ocr_dataset/000105.jpg	h
# datasets/ocr_dataset/000106.jpg	smith
# datasets/ocr_dataset/000107.jpg	w
# datasets/ocr_dataset/000108.jpg	high
# datasets/ocr_dataset/000109.jpg	shops
# datasets/ocr_dataset/000110.jpg	yard
# datasets/ocr_dataset/000111.jpg	m
# datasets/ocr_dataset/000112.jpg	tm
# datasets/ocr_dataset/000113.jpg	j
# datasets/ocr_dataset/000114.jpg	rough
# datasets/ocr_dataset/000115.jpg	java
# datasets/ocr_dataset/000116.jpg	soap
# datasets/ocr_dataset/000117.jpg	wrox
# datasets/ocr_dataset/000118.jpg	form
# datasets/ocr_dataset/000119.jpg	da
# datasets/ocr_dataset/000120.jpg	post
# datasets/ocr_dataset/000121.jpg	lock
# datasets/ocr_dataset/000122.jpg	h
# datasets/ocr_dataset/000123.jpg	fca
# datasets/ocr_dataset/000124.jpg	royal
# datasets/ocr_dataset/000125.jpg	hsbc
# datasets/ocr_dataset/000126.jpg	local
# datasets/ocr_dataset/000127.jpg	ltd
# datasets/ocr_dataset/000128.jpg	1996
# datasets/ocr_dataset/000129.jpg	547
# datasets/ocr_dataset/000130.jpg	a
# datasets/ocr_dataset/000131.jpg	a
# datasets/ocr_dataset/000132.jpg	act
# datasets/ocr_dataset/000133.jpg	of
# datasets/ocr_dataset/000134.jpg	or
# datasets/ocr_dataset/000135.jpg	school
# datasets/ocr_dataset/000136.jpg	to
# datasets/ocr_dataset/000137.jpg	yarmouth
# datasets/ocr_dataset/000138.jpg	a133
# datasets/ocr_dataset/000139.jpg	gt
# datasets/ocr_dataset/000140.jpg	harwich
# datasets/ocr_dataset/000141.jpg	ipswich
# datasets/ocr_dataset/000142.jpg	ford
# datasets/ocr_dataset/000143.jpg	2
# datasets/ocr_dataset/000144.jpg	2
# datasets/ocr_dataset/000145.jpg	s
# datasets/ocr_dataset/000146.jpg	cask
# datasets/ocr_dataset/000147.jpg	food
# datasets/ocr_dataset/000148.jpg	good
# datasets/ocr_dataset/000149.jpg	traffic
# datasets/ocr_dataset/000150.jpg	a134
# datasets/ocr_dataset/000151.jpg	asda
# datasets/ocr_dataset/000152.jpg	food
# datasets/ocr_dataset/000153.jpg	p
# datasets/ocr_dataset/000154.jpg	park
# datasets/ocr_dataset/000155.jpg	sats
# datasets/ocr_dataset/000156.jpg	car
# datasets/ocr_dataset/000157.jpg	park
# datasets/ocr_dataset/000158.jpg	way
# datasets/ocr_dataset/000159.jpg	of
# datasets/ocr_dataset/000160.jpg	out
# datasets/ocr_dataset/000161.jpg	risk
# datasets/ocr_dataset/000162.jpg	your
# datasets/ocr_dataset/000163.jpg	asda
# datasets/ocr_dataset/000164.jpg	stop
# datasets/ocr_dataset/000165.jpg	to
# datasets/ocr_dataset/000166.jpg	a
# datasets/ocr_dataset/000167.jpg	just
# datasets/ocr_dataset/000168.jpg	asda
# datasets/ocr_dataset/000169.jpg	asda
# datasets/ocr_dataset/000170.jpg	low
# datasets/ocr_dataset/000171.jpg	mail
# datasets/ocr_dataset/000172.jpg	royal
# datasets/ocr_dataset/000173.jpg	2002
# datasets/ocr_dataset/000174.jpg	xvii
# datasets/ocr_dataset/000175.jpg	f
# datasets/ocr_dataset/000176.jpg	o
# datasets/ocr_dataset/000177.jpg	r
# datasets/ocr_dataset/000178.jpg	17
# datasets/ocr_dataset/000179.jpg	59
# datasets/ocr_dataset/000180.jpg	draught
# datasets/ocr_dataset/000181.jpg	tm
# datasets/ocr_dataset/000182.jpg	r
# datasets/ocr_dataset/000183.jpg	from
# datasets/ocr_dataset/000184.jpg	15
# datasets/ocr_dataset/000185.jpg	3
# datasets/ocr_dataset/000186.jpg	u
# datasets/ocr_dataset/000187.jpg	133
# datasets/ocr_dataset/000188.jpg	a
# datasets/ocr_dataset/000189.jpg	gt
# datasets/ocr_dataset/000190.jpg	harwich
# datasets/ocr_dataset/000191.jpg	ipswich
# datasets/ocr_dataset/000192.jpg	world
# datasets/ocr_dataset/000193.jpg	yarmouth
# datasets/ocr_dataset/000194.jpg	ipswich
# datasets/ocr_dataset/000195.jpg	road
# datasets/ocr_dataset/000196.jpg	isuzu
# datasets/ocr_dataset/000197.jpg	your
# datasets/ocr_dataset/000198.jpg	m
# datasets/ocr_dataset/000199.jpg	o
# datasets/ocr_dataset/000200.jpg	t
# datasets/ocr_dataset/000201.jpg	school
# datasets/ocr_dataset/000202.jpg	good
# datasets/ocr_dataset/000203.jpg	h
# datasets/ocr_dataset/000204.jpg	t
# datasets/ocr_dataset/000205.jpg	w
# datasets/ocr_dataset/000206.jpg	hair
# datasets/ocr_dataset/000207.jpg	fax
# datasets/ocr_dataset/000208.jpg	coral
# datasets/ocr_dataset/000209.jpg	walk
# datasets/ocr_dataset/000210.jpg	dark
# datasets/ocr_dataset/000211.jpg	airtours
# datasets/ocr_dataset/000212.jpg	holidays
# datasets/ocr_dataset/000213.jpg	lloyds
# datasets/ocr_dataset/000214.jpg	photo
# datasets/ocr_dataset/000215.jpg	british
# datasets/ocr_dataset/000216.jpg	cross
# datasets/ocr_dataset/000217.jpg	shop
# datasets/ocr_dataset/000218.jpg	café
# datasets/ocr_dataset/000219.jpg	sack
# datasets/ocr_dataset/000220.jpg	sad
# datasets/ocr_dataset/000221.jpg	box
# datasets/ocr_dataset/000222.jpg	8000
# datasets/ocr_dataset/000223.jpg	my
# datasets/ocr_dataset/000224.jpg	compact
# datasets/ocr_dataset/000225.jpg	daily
# datasets/ocr_dataset/000226.jpg	july
# datasets/ocr_dataset/000227.jpg	2002
# datasets/ocr_dataset/000228.jpg	28
# datasets/ocr_dataset/000229.jpg	airshow
# datasets/ocr_dataset/000230.jpg	a
# datasets/ocr_dataset/000231.jpg	foc
# datasets/ocr_dataset/000232.jpg	of
# datasets/ocr_dataset/000233.jpg	to
# datasets/ocr_dataset/000234.jpg	visits
# datasets/ocr_dataset/000235.jpg	a
# datasets/ocr_dataset/000236.jpg	a
# datasets/ocr_dataset/000237.jpg	but
# datasets/ocr_dataset/000238.jpg	fool
# datasets/ocr_dataset/000239.jpg	his
# datasets/ocr_dataset/000240.jpg	his
# datasets/ocr_dataset/000241.jpg	is
# datasets/ocr_dataset/000242.jpg	is
# datasets/ocr_dataset/000243.jpg	mouth
# datasets/ocr_dataset/000244.jpg	mouth
# datasets/ocr_dataset/000245.jpg	of
# datasets/ocr_dataset/000246.jpg	of
# datasets/ocr_dataset/000247.jpg	bostock
# datasets/ocr_dataset/000248.jpg	marisa
# datasets/ocr_dataset/000249.jpg	iiyama
# datasets/ocr_dataset/000250.jpg	pro
# datasets/ocr_dataset/000251.jpg	x
# datasets/ocr_dataset/000252.jpg	xtra
# datasets/ocr_dataset/000253.jpg	g
# datasets/ocr_dataset/000254.jpg	group
# datasets/ocr_dataset/000255.jpg	i
# datasets/ocr_dataset/000256.jpg	i
# datasets/ocr_dataset/000257.jpg	of
# datasets/ocr_dataset/000258.jpg	digital
# datasets/ocr_dataset/000259.jpg	group
# datasets/ocr_dataset/000260.jpg	hp
# datasets/ocr_dataset/000261.jpg	r
# datasets/ocr_dataset/000262.jpg	microsoft
# datasets/ocr_dataset/000263.jpg	caps
# datasets/ocr_dataset/000264.jpg	lock
# datasets/ocr_dataset/000265.jpg	loxk
# datasets/ocr_dataset/000266.jpg	loxk
# datasets/ocr_dataset/000267.jpg	scroll
# datasets/ocr_dataset/000268.jpg	raf
# datasets/ocr_dataset/000269.jpg	77
# datasets/ocr_dataset/000270.jpg	cd
# datasets/ocr_dataset/000271.jpg	matsui
# datasets/ocr_dataset/000272.jpg	flash
# datasets/ocr_dataset/000273.jpg	4
# datasets/ocr_dataset/000274.jpg	books
# datasets/ocr_dataset/000275.jpg	last
# datasets/ocr_dataset/000276.jpg	word
# datasets/ocr_dataset/000277.jpg	d
# datasets/ocr_dataset/000278.jpg	disturb
# datasets/ocr_dataset/000279.jpg	do
# datasets/ocr_dataset/000280.jpg	im
# datasets/ocr_dataset/000281.jpg	s
# datasets/ocr_dataset/000282.jpg	this
# datasets/ocr_dataset/000283.jpg	to
# datasets/ocr_dataset/000284.jpg	work
# datasets/ocr_dataset/000285.jpg	footpath
# datasets/ocr_dataset/000286.jpg	to
# datasets/ocr_dataset/000287.jpg	campus
# datasets/ocr_dataset/000288.jpg	st
# datasets/ocr_dataset/000289.jpg	2a
# datasets/ocr_dataset/000290.jpg	544444
# datasets/ocr_dataset/000291.jpg	arthur
# datasets/ocr_dataset/000292.jpg	fours
# datasets/ocr_dataset/000293.jpg	taxi
# datasets/ocr_dataset/000294.jpg	gym
# datasets/ocr_dataset/000295.jpg	at
# datasets/ocr_dataset/000296.jpg	of
# datasets/ocr_dataset/000297.jpg	room
# datasets/ocr_dataset/000298.jpg	room
# datasets/ocr_dataset/000299.jpg	bar
# datasets/ocr_dataset/000300.jpg	book
# datasets/ocr_dataset/000301.jpg	word
# datasets/ocr_dataset/000302.jpg	push
# datasets/ocr_dataset/000303.jpg	pull
# datasets/ocr_dataset/000304.jpg	glass
# datasets/ocr_dataset/000305.jpg	of
# datasets/ocr_dataset/000306.jpg	toyota
# datasets/ocr_dataset/000307.jpg	studio
# datasets/ocr_dataset/000308.jpg	mark
# datasets/ocr_dataset/000309.jpg	out
# datasets/ocr_dataset/000310.jpg	way
# datasets/ocr_dataset/000311.jpg	barclays
# datasets/ocr_dataset/000312.jpg	campus
# datasets/ocr_dataset/000313.jpg	shop
# datasets/ocr_dataset/000314.jpg	xml
# datasets/ocr_dataset/000315.jpg	java
# datasets/ocr_dataset/000316.jpg	just
# datasets/ocr_dataset/000317.jpg	to
# datasets/ocr_dataset/000318.jpg	u
# datasets/ocr_dataset/000319.jpg	a
# datasets/ocr_dataset/000320.jpg	u
# datasets/ocr_dataset/000321.jpg	to
# datasets/ocr_dataset/000322.jpg	a
# datasets/ocr_dataset/000323.jpg	tramp
# datasets/ocr_dataset/000324.jpg	u
# datasets/ocr_dataset/000325.jpg	may
# datasets/ocr_dataset/000326.jpg	but
# datasets/ocr_dataset/000327.jpg	do
# datasets/ocr_dataset/000328.jpg	you
# datasets/ocr_dataset/000329.jpg	30
# datasets/ocr_dataset/000330.jpg	88
# datasets/ocr_dataset/000331.jpg	d
# datasets/ocr_dataset/000332.jpg	sword
# datasets/ocr_dataset/000333.jpg	scottish
# datasets/ocr_dataset/000334.jpg	1898
# datasets/ocr_dataset/000335.jpg	1809
# datasets/ocr_dataset/000336.jpg	hall
# datasets/ocr_dataset/000337.jpg	of
# datasets/ocr_dataset/000338.jpg	dollar
# datasets/ocr_dataset/000339.jpg	sc
# datasets/ocr_dataset/000340.jpg	4
# datasets/ocr_dataset/000341.jpg	for
# datasets/ocr_dataset/000342.jpg	club
# datasets/ocr_dataset/000343.jpg	dollar
# datasets/ocr_dataset/000344.jpg	golf
# datasets/ocr_dataset/000345.jpg	club
# datasets/ocr_dataset/000346.jpg	adt
# datasets/ocr_dataset/000347.jpg	dollar
# datasets/ocr_dataset/000348.jpg	arms
# datasets/ocr_dataset/000349.jpg	footway
# datasets/ocr_dataset/000350.jpg	for
# datasets/ocr_dataset/000351.jpg	450
# datasets/ocr_dataset/000352.jpg	yds
# datasets/ocr_dataset/000353.jpg	ol
# datasets/ocr_dataset/000354.jpg	volvo
# datasets/ocr_dataset/000355.jpg	volvo
# datasets/ocr_dataset/000356.jpg	b
# datasets/ocr_dataset/000357.jpg	bjork
# datasets/ocr_dataset/000358.jpg	18
# datasets/ocr_dataset/000359.jpg	8
# datasets/ocr_dataset/000360.jpg	moto
# datasets/ocr_dataset/000361.jpg	1l
# datasets/ocr_dataset/000362.jpg	vodka
# datasets/ocr_dataset/000363.jpg	zubrowka
# datasets/ocr_dataset/000364.jpg	for
# datasets/ocr_dataset/000365.jpg	uk
# datasets/ocr_dataset/000366.jpg	liquid
# datasets/ocr_dataset/000367.jpg	up
# datasets/ocr_dataset/000368.jpg	alarm
# datasets/ocr_dataset/000369.jpg	call
# datasets/ocr_dataset/000370.jpg	you
# datasets/ocr_dataset/000371.jpg	to
# datasets/ocr_dataset/000372.jpg	iiyama
# datasets/ocr_dataset/000373.jpg	boards
# datasets/ocr_dataset/000374.jpg	is
# datasets/ocr_dataset/000375.jpg	light
# datasets/ocr_dataset/000376.jpg	do
# datasets/ocr_dataset/000377.jpg	if
# datasets/ocr_dataset/000378.jpg	lift
# datasets/ocr_dataset/000379.jpg	will
# datasets/ocr_dataset/000380.jpg	will
# datasets/ocr_dataset/000381.jpg	without
# datasets/ocr_dataset/000382.jpg	you
# datasets/ocr_dataset/000383.jpg	alarm
# datasets/ocr_dataset/000384.jpg	alarm
# datasets/ocr_dataset/000385.jpg	at
# datasets/ocr_dataset/000386.jpg	at
# datasets/ocr_dataset/000387.jpg	4
# datasets/ocr_dataset/000388.jpg	floor
# datasets/ocr_dataset/000389.jpg	of
# datasets/ocr_dataset/000390.jpg	out
# datasets/ocr_dataset/000391.jpg	sorry

# %%
import os

root_dir = save_dir
img_paths = []
labels = []

# Read labels from text file
with open(os.path.join(root_dir, "labels.txt"), "r") as f:
    for label in f:
        labels.append(label.strip().split("\t")[1])
        img_paths.append(label.strip().split("\t")[0])

print(f"Total images: {len(img_paths)}")
# Out:
# Total images: 392

# %%
# Create a list of unique characters from the labels
letters = [char.split(".")[0].lower() for char in labels]
letters = "".join(letters)
letters = sorted(list(set(list(letters))))

# Create a string of all characters in the dataset
chars = "".join(letters)

# Add a blank character
blank_char = "-"
chars += blank_char

# Calculate the vocabulary size
vocab_size = len(chars)

print(f"Vocab: {chars}")
print(f"Vocab size: {vocab_size}")
# Out:
# Vocab: 0123456789abcdfghijklmopqrstuvwxyzé-
# Vocab size: 36

# %%
char_to_idx = {char: idx + 1 for idx, char in enumerate(sorted(chars))}
idx_to_char = {index: char for char, index in char_to_idx.items()}

print(char_to_idx)
print(idx_to_char)
# Out:
# {'-': 1, '0': 2, '1': 3, '2': 4, '3': 5, '4': 6, '5': 7, '6': 8, '7': 9, '8': 10, '9': 11, 'a': 12, 'b': 13, 'c': 14, 'd': 15, 'f': 16, 'g': 17, 'h': 18, 'i': 19, 'j': 20, 'k': 21, 'l': 22, 'm': 23, 'o': 24, 'p': 25, 'q': 26, 'r': 27, 's': 28, 't': 29, 'u': 30, 'v': 31, 'w': 32, 'x': 33, 'y': 34, 'z': 35, 'é': 36}
# {1: '-', 2: '0', 3: '1', 4: '2', 5: '3', 6: '4', 7: '5', 8: '6', 9: '7', 10: '8', 11: '9', 12: 'a', 13: 'b', 14: 'c', 15: 'd', 16: 'f', 17: 'g', 18: 'h', 19: 'i', 20: 'j', 21: 'k', 22: 'l', 23: 'm', 24: 'o', 25: 'p', 26: 'q', 27: 'r', 28: 's', 29: 't', 30: 'u', 31: 'v', 32: 'w', 33: 'x', 34: 'y', 35: 'z', 36: 'é'}

# %%
max_label_len = max([len(label) for label in labels])

def encode(label, char_to_idx, max_label_len):
    encoded_labels = torch.tensor(
        [char_to_idx[char] for char in label],
        dtype=torch.int32
    )
    label_len = len(encoded_labels)
    lengths = torch.tensor(
        label_len,
        dtype=torch.int32
    )
    padded_labels = F.pad(
        encoded_labels,
        (0, max_label_len - label_len),
        value=0
    )
    return padded_labels, lengths

# %%
def decode(encoded_sequences, idx_to_char, blank_char="-"):
    decoded_sequences = []
    for seq in encoded_sequences:
        decoded_label = []
        prev_char = None  # To track the previous character

        for token in seq:
            if token != 0:  # Ignore padding (token = 0)
                char = idx_to_char[token.item()]
                # Append the character if it's not a blank or the same as the previous character
                if char != blank_char:
                    if char != prev_char or prev_char == blank_char:
                        decoded_label.append(char)
                    prev_char = char  # Update previous character

        decoded_sequences.append("".join(decoded_label))

    print(f"From {encoded_sequences} to {decoded_sequences}")
    return decoded_sequences

# %%
from torchvision import transforms

data_transforms = {
    "train": transforms.Compose(
        [
            transforms.Resize((100, 420)),
            transforms.ColorJitter(
                brightness=0.5,
                contrast=0.5,
                saturation=0.5,
            ),
            transforms.Grayscale(
                num_output_channels=1,
            ),
            transforms.GaussianBlur(3),
            transforms.RandomAffine(
                degrees=1,
                shear=1,
            ),
            transforms.RandomPerspective(
                distortion_scale=0.3,
                p=0.5,
                interpolation=3,
            ),
            transforms.RandomRotation(degrees=2),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,)),
        ]
    ),
    "val": transforms.Compose(
        [
            transforms.Resize((100, 420)),
            transforms.Grayscale(num_output_channels=1),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,)),
        ]
    ),
}

# %%
from sklearn.model_selection import train_test_split

seed = 0
val_size = 0.1
test_size = 0.1
is_shuffle = True

# Assuming img_paths and labels are already defined
X_train, X_val, y_train, y_val = train_test_split(
    img_paths,
    labels,
    test_size=val_size,
    random_state=seed,
    shuffle=is_shuffle,
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train,
    y_train,
    test_size=test_size,
    random_state=seed,
    shuffle=is_shuffle,
)

# %%
from torch.utils.data import Dataset
from PIL import Image

class STRDataset(Dataset):
    def __init__(self, X, y, char_to_idx, max_label_len, label_encoder=None, transform=None):
        self.transform = transform
        self.img_paths = X
        self.labels = y
        self.char_to_idx = char_to_idx
        self.max_label_len = max_label_len
        self.label_encoder = label_encoder

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        label = self.labels[idx]
        img_path = self.img_paths[idx]
        img = Image.open(img_path).convert("RGB")

        if self.transform:
            img = self.transform(img)

        if self.label_encoder:
            encoded_label, label_len = self.label_encoder(label, self.char_to_idx, self.max_label_len)
            return img, encoded_label, label_len

        return img, label

# %%
from torch.utils.data import DataLoader

train_dataset = STRDataset(
    X_train,
    y_train,
    char_to_idx=char_to_idx,
    max_label_len=max_label_len,
    label_encoder=encode,
    transform=data_transforms["train"],
)
val_dataset = STRDataset(
    X_val,
    y_val,
    char_to_idx=char_to_idx,
    max_label_len=max_label_len,
    label_encoder=encode,
    transform=data_transforms["val"],
)
test_dataset = STRDataset(
    X_test,
    y_test,
    char_to_idx=char_to_idx,
    max_label_len=max_label_len,
    label_encoder=encode,
    transform=data_transforms["val"],
)

train_batch_size = 64
test_batch_size = 64 * 2

train_loader = DataLoader(
    train_dataset,
    batch_size=train_batch_size,
    shuffle=True,
)
val_loader = DataLoader(
    val_dataset,
    batch_size=test_batch_size,
    shuffle=False,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False,
)

# %%
import torch
import timm

import torch.nn as nn

class CRNN(nn.Module):
    def __init__(self, vocab_size, hidden_size, n_layers, dropout=0.2, unfreeze_layers=3):
        super(CRNN, self).__init__()

        backbone = timm.create_model("resnet152", in_chans=1, pretrained=True)
        modules = list(backbone.children())[:-2]
        modules.append(nn.AdaptiveAvgPool2d((1, None)))
        self.backbone = nn.Sequential(*modules)

        # Unfreeze the last few layers
        for parameter in self.backbone[-unfreeze_layers:].parameters():
            parameter.requires_grad = True

        self.mapSeq = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        self.gru = nn.GRU(
            512,
            hidden_size,
            n_layers,
            bidirectional=True,
            batch_first=True,
            dropout=dropout if n_layers > 1 else 0,
        )
        self.layer_norm = nn.LayerNorm(hidden_size * 2)

        self.out = nn.Sequential(
            nn.Linear(hidden_size * 2, vocab_size),
            nn.LogSoftmax(dim=2)
        )

    @torch.autocast(device_type="cuda")
    def forward(self, x):
        x = self.backbone(x)
        x = x.permute(0, 3, 1, 2)
        x = x.view(x.size(0), x.size(1), -1)  # Flatten the feature map
        x = self.mapSeq(x)
        x, _ = self.gru(x)
        x = self.layer_norm(x)
        x = self.out(x)
        x = x.permute(1, 0, 2)  # Based on CTC

        return x

# %%
hidden_size = 256
n_layers = 3
dropout_prob = 0.2
unfreeze_layers = 3
device = "cuda" if torch.cuda.is_available() else "cpu"

model = CRNN(
    vocab_size=vocab_size,
    hidden_size=hidden_size,
    n_layers=n_layers,
    dropout=dropout_prob,
    unfreeze_layers=unfreeze_layers,
).to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]

# %%
import time
import torch

def evaluate(model, dataloader, criterion, device):
    model.eval()
    losses = []
    with torch.no_grad():
        for inputs, labels, labels_len in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            labels_len = labels_len.to(device)

            outputs = model(inputs)
            logits_lens = torch.full(
                size=(outputs.size(1),), fill_value=outputs.size(0), dtype=torch.long
            ).to(device)

            loss = criterion(outputs, labels, logits_lens, labels_len)
            losses.append(loss.item())

    loss = sum(losses) / len(losses)
    return loss

def fit(model, train_loader, val_loader, criterion, optimizer, scheduler, device, epochs):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        start = time.time()

        batch_train_losses = []

        model.train()
        for idx, (inputs, labels, labels_len) in enumerate(train_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            labels_len = labels_len.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)

            logits_lens = torch.full(
                size=(outputs.size(1),),
                fill_value=outputs.size(0),
                dtype=torch.long,
            ).to(device)

            loss = criterion(outputs, labels, logits_lens, labels_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
            optimizer.step()

            batch_train_losses.append(loss.item())

        train_loss = sum(batch_train_losses) / len(batch_train_losses)
        train_losses.append(train_loss)

        val_loss = evaluate(model, val_loader, criterion, device)
        val_losses.append(val_loss)

        print(
            f"EPOCH {epoch + 1}:\tTrain loss: {train_loss:.4f}\tVal loss: {val_loss:.4f}\t